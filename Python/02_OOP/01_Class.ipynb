# %% [markdown]
# # **1. Atm Working**

# %%
class Atm:
    # Static/class variable 
    __counter = 1

    # Constructor
    def __init__(self):
        self.__pin='' # __ is used to private the variable , we can also private our methods
        self.__balance=0 
        self.sno = Atm.__counter
        Atm.__counter = Atm.__counter +1

        # self.menu()

    # Methods
    def menu(self):
        user_input = input('''
            Hello, How would you like to proceed?
            1. Press 1 to Create Pin
            2. Press 2 to Deposit
            3. Press 3 to Withdraw
            4. Press 4 to Check Your Balance
            5. Press 5 to Exit
            ''')
        
        if user_input=='1':
            self.create_pin()
        elif user_input=='2':
            self.deposite()
        elif user_input=='3':
            self.withdraw()
        elif user_input=='4':
            self.balance_check()
        else:
            print("Bye")
    
    
    def create_pin(self):
        self.__pin = input("Enter the Pin You Want to Create")
        print("Pin has been Created Successfully!")

    def deposite(self):
        temp = input("Enter Your Pin")
        if temp == self.__pin:
            amount = int(input("Enter the Amount You Want to Deposite"))
            self.__balance = self.__balance + amount
            print("Your Amount has been deposited successfully!")
        else:
            print("Invalid Pin!")
    
    def withdraw(self):
        temp = input("Enter Your Pin")
        if temp==self.__pin:
            amount = int(input("Enter the Amount You Want to Withdraw"))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print("Your Amount has been Withdrawn successfully!")
            else:
                print("Insufficient Amount")
        else:
            print("Invalid Pin!")

    def balance_check(self):

        temp = input("Enter Your Pin")
        if temp == self.__pin:
            print(f"Your Current Balance is {self.__balance}")
        else:
            print("Invalid Pin!")

    ''' ----------------GETTER----------------
    (A getter is a method that retrieves the value of a private attribute. 
    It allows you to read the value without directly accessing the attribute.)'''

    def get_pin(self):
        return self.__pin
    
    @staticmethod
    def get_counter():
        return Atm.__counter
    

    ''' ----------------SETTER----------------
    (A setter is a method that sets or updates the value of a private attribute.
    It allows you to include validation or processing logic before changing the attribute's value.)'''

    def set_pin(self,new_pin):
        if isinstance(new_pin,str):
            self.__pin = new_pin
            print("The PIN has been changed.")
        else:
            raise ValueError("The PIN must be a string.")
        
    @staticmethod
    def set_counter(new):
        if type(new) == int:
            Atm.__counter == new
        else:
            print("Not Allowed")

# %%
sbi = Atm()
sbi.get_counter()
# Out:
# 2

# %%
# sbi.balance_check()

# %%
# sbi.deposite()

# %%
# sbi.balance_check()

# %%
# sbi.withdraw()

# %%
# sbi.balance_check()

# %%
pin = sbi.get_pin()
pin
# Out:
# ''

# %%
sbi.set_pin("123")
# Out:
# The PIN has been changed.

# %% [markdown]
# # **2. Fraction Data Type**

# %%
class Fraction:

    # Constructor
    def __init__(self,num,den):
        self.num = num
        self.den = den
    
    # Methods
    def __str__(self):
        return ("{}/{}").format(self.num,self.den)
    
    # Addition
    def __add__(self,other):
        temp_num = self.num * other.den + other.num * self.den
        temp_den = self.den * other.den
        return ("{}/{}").format(temp_num,temp_den)
    # Subtraction 
    def __sub__(self,other):
        temp_num = self.num * other.den - other.num * self.den
        temp_den = self.den * other.den
        return ("{}/{}").format(temp_num,temp_den)
    # Multiplication 
    def __mul__(self,other):
        temp_num = self.num * other.num 
        temp_den = self.den * other.den
        return ("{}/{}").format(temp_num,temp_den)
    # Division 
    def __truediv__(self,other):
        temp_num = self.num * other.den 
        temp_den = self.den * other.num
        return ("{}/{}").format(temp_num,temp_den)

# %%
x= Fraction(9,8)
y= Fraction(4,6)

# %%
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 86/48
# 22/48
# 36/48
# 54/32

# %% [markdown]
# # **3. Refer by Name**

# %%
class Customer:

    def __init__(self,name,gender):
        self.name = name
        self.gender = gender

# %%
cust = Customer("Mirza","Male")

# %%
def greet(customer):
    if customer.gender == 'Male':
        print(f"Hello {customer.name} sir!")
    else:
        print(f"Hello {customer.name} ma'am!")

# %%
greet(cust)
# Out:
# Hello Mirza sir!

# %%
cust1 = Customer("Maria","Female")

# %%
greet(cust1)
# Out:
# Hello Maria ma'am!

# %% [markdown]
# # **4. Aggrigation Relationship**

# %%
class Customer:
    # Constructor
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address
    
    # Method For Edit Profile
    def edit_profile(self, new_name=None, new_city=None, new_pincode=None, new_state=None):
        if new_name is not None:
            self.name = new_name
        if new_city is not None or new_pincode is not None or new_state is not None:
            self.address.change_add(new_city, new_pincode, new_state)



class Address:
    # Constructor
    def __init__(self,city,pincode,state):
        self.city = city
        self.pincode = pincode
        self.state = state
    
    # method Change Address
    def change_add(self,new_city,new_pincode,new_state):
        self.city = new_city
        self.pincode = new_pincode
        self.state = new_state

# %%
add = Address('Pakpattan','57400','punjab')
cus = Customer('Kaleem','male',add)

# %%
cus.edit_profile(new_city='Karachi',new_pincode=54700,new_name='Raza',new_state='Sindh')

# %%
cus.address.city
# Out:
# 'Karachi'

# %% [markdown]
# # **5. Inheritance**

# %%
class User:
    def login():
        print("Loged in")
    def register():
        print("Registered")

'''
It is condition for both students and teachers to login and register in the Udemy website.
So we Inherit these features of User Class.
'''

class Student(User): # class student is inheriting class User
    def enroll():
        print("Enrolled")
    def review():
        print("Reviewed")

class Teacher(User):
    def create_class():
        print("Class Created")
    def answer():
        print("Answer the Questions")

# %%
stu = Student.login
tec = Teacher.login

# %%
# A Parent class cannot inherit the code of child class
u = User()
u.review
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 3
#       1 # A Parent class cannot inherit the code of child class
#       2 u = User()
# ----> 3 u.review
#
# AttributeError: 'User' object has no attribute 'review'

# %%
class Phone:
    def __init__(self,brand,price,camera):
        print("Inside the Phone Constructor")
        self.brand = brand
        self.price = price
        self.__camera = camera
    
    def buy(self):
        print("Buying a Phone")

class SmartPhone(Phone):
    
    def buy(self):
        print("Buying a Smart Phone")

# %%
s = SmartPhone("Apple",10000,13)
# Out:
# Inside the Phone Constructor

# %%
s.brand
# Out:
# 'Apple'

# %%
# methods with same name in both classes
s.buy() # Method Over-riding [concept of Polymorphism]
# Out:
# Buying a Smart Phone

# %%
# We cannot inherit the private members
s.__camera
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 2
#       1 # We cannot inherit the private members
# ----> 2 s.__camera
#
# AttributeError: 'SmartPhone' object has no attribute '__camera'

# %% [markdown]
# ## **Types of Inheritence**
# ### **i. Single-Level-Inheritence**

# %%
class Phone:
    def __init__(self,brand,price,camera):
        print("Inside the Phone Constructor")
        self.brand = brand
        self.price = price
        self.__camera = camera
    
    def buy(self):
        print("Buying a Phone")

class SmartPhone(Phone):
    
    def buy(self):
        print("Buying a Smart Phone")

# %%
obj_s = SmartPhone("Vivo",40000,13)
obj_s.buy()
# Out:
# Inside the Phone Constructor
# Buying a Smart Phone

# %% [markdown]
# ### **ii. Multi-Level-Inheritence**

# %%
class Grandparent:
    def show(self):
        print("Grandparent class")

class Parent(Grandparent):
    def display(self):
        print("Parent class")

class Child(Parent):
    def talk(self):
        print("Child class")

# Usage
child = Child()
child.show()    # Output: Grandparent class
child.display()  # Output: Parent class
# Out:
# Grandparent class
# Parent class

# %% [markdown]
# ### **iii. Multiple Inheritence**

# %%
class Parent1:
    def show1(self):
        print("Parent 1")

class Parent2:
    def show2(self):
        print("Parent 2")

class Child(Parent1, Parent2):
    def display(self):
        print("Child class")

# Usage
child = Child()
child.show1()  # Output: Parent 1
child.show2()  # Output: Parent 2
# Out:
# Parent 1
# Parent 2

# %% [markdown]
# # **6. Polymorphism**

# %% [markdown]
# ## **i. Method Overriding**

# %%
# Inheriting the constructor
class Phone:
    def __init__(self,brand,price,camera):
        print("Inside the Phone Constructor")
        self.brand = brand
        self.price = price
        self.__camera = camera
    
    def buy(self):
        print("Buying a Phone")

class SmartPhone(Phone):
    
    def buy(self):
        print("Buying a Smart Phone")

# %%
# method overriding
s = SmartPhone('Apple',20000,13)
s.buy()
# Out:
# Inside the Phone Constructor
# Buying a Smart Phone

# %% [markdown]
# ## **ii. Super()**
# - Use to access the method and constructor of Parent Class

# %%
# Inheriting the constructor
class Phone:
    def __init__(self,brand,price,camera):
        print("Inside the Phone Constructor")
        self.brand = brand
        self.price = price
        self.__camera = camera
    
    def buy(self):
        print("Buying a Phone")

class SmartPhone(Phone):
    
    def buy(self):
        print("Buying a Smart Phone")
        super().buy() # Use to access the method  of Parent Class

# %%
# method overriding
s = SmartPhone('Apple',20000,13)
s.buy()
# Out:
# Inside the Phone Constructor
# Buying a Smart Phone
# Buying a Phone

# %%
# Inheriting the constructor
class Phone:
    def __init__(self,brand,price,camera):
        print("Inside the Phone Constructor")
        self.brand = brand
        self.__price = price
        self.camera = camera
    
    def buy(self):
        print("Buying a Phone")

class SmartPhone(Phone):
    def __init__(self,brand,price,camera,os,ram):
        super().__init__(brand,price,camera) # accessing the Parent Constructor and should be first statement
        self.os = os
        self.ram =ram
        print("Insidet the SmartPhone Constructor")

        def buy(self):
            print("Buying a Smart Phone")

# %%
s = SmartPhone("Oppo",65000,32,'Andriod',8)
print(s.brand)
print(s.os)
print(s.ram)
print(s.camera)
# Out:
# Inside the Phone Constructor
# Insidet the SmartPhone Constructor
# Oppo
# Andriod
# 8
# 32

# %% [markdown]
# ## **iii. Method Overloading**

# %%
class Geometry:
    def area(self,radius):
        print("Area of Circle",3.14*radius*radius)

    def area(self,lenght,width):
        print("Area of Rectangle",lenght*width)

obj = Geometry()
obj.area(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       6         print("Area of Rectangle",lenght*width)
#       8 obj = Geometry()
# ----> 9 obj.area(4)
#
# TypeError: Geometry.area() missing 1 required positional argument: 'width'

# %% [markdown]
# `Note:`In other languages like java and c++ obove code was correct,but in python technically there is no method overloding. We can achieve it through default arguments.

# %%
class Geometry:
    def area(self,a,b=0):
        if b == 0:
            print("Area of Circle",3.14*a*a)
        else:
            print("Area of Rectangle",a*b)

obj = Geometry()
print(obj.area(3))
print(obj.area(2,3))
# Out:
# Area of Circle 28.259999999999998
# None
# Area of Rectangle 6
# None

# %% [markdown]
# ## **iv. Operator Overloading**

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    
    def add_points(self, other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x, y)
    
    
p1 = Point(1, 2)
p2 = Point(2, 3)

p3 = p1.add_points(p2)

print((p3.x, p3.y))
# Out:
# (3, 5)
