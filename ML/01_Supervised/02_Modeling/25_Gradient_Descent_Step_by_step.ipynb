# %% [markdown]
# # **Gradient Descent**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1,noise=80,random_state=13)

# %%
plt.scatter(X,y);

# %%
# Lets apply ols
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red');

# %% [markdown]
# ## **1. With Constant value of m**

# %%
""" Lets apply Gradient Descent assuming slope is constant m = 78.35
and let's assume the starting value for intercept b = 0 """
b=0
m=78.35
y_pred=((m*X)+b)

# %%
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, reg.predict(X), color='red', label='OLS')  # Original Least Squares line

plt.plot(X, y_pred, color='#1f77b4', label='b = {}'.format(b))                 
   
plt.legend()
plt.title("Different Predictions for Changing b")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %%
m=78.35
slope=-2 * np.sum(y - (m * X.ravel()) - b)
slope
# Out:
# -209.27763408209216

# %%
# let take the learning rate 0.1
lr=0.1

step_size=lr*slope
step_size
# Out:
# -20.927763408209216

# %%
b = b - step_size
b
# Out:
# 20.927763408209216

# %%
y_pred1 = ((78.35 * X) + b).reshape(4)

# %%
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, reg.predict(X), color='red', label='OLS')  # Original Least Squares line

plt.plot(X, y_pred, color='#1f77b4', label='b = {}'.format(b))        
plt.plot(X, y_pred1, color='#ff7f0e', label='b = {}'.format(b))           
   
plt.legend()
plt.title("Different Predictions for Changing b")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %%
# Iteration 2
slope=-2 * np.sum(y - m*X.ravel()+b)
slope
# Out:
# -376.6997413477659

# %%
step_size=slope*lr
step_size
# Out:
# -37.66997413477659

# %%
b= b-step_size
b
# Out:
# 58.597737542985804

# %%
y_pred2 = ((m * X) + b).reshape(4)

# %%
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, reg.predict(X), color='red', label='OLS')  # Original Least Squares line

plt.plot(X, y_pred, color='#1f77b4', label='b = {}'.format(b))        
plt.plot(X, y_pred1, color='#ff7f0e', label='b = {}'.format(b))      
plt.plot(X, y_pred2, color='#2ca02c', label='b = {}'.format(b))         
   
plt.legend()
plt.title("Different Predictions for Changing b")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %%
# iteration 3
slope=-2 * np.sum(y - (m * X.ravel()) - b)
slope
# Out:
# 259.50426626179427

# %%
step_size=lr * slope
step_size
# Out:
# 25.95042662617943

# %%
b = b - step_size
b
# Out:
# 32.647310916806376

# %%
y_pred3=((m * X) + b).reshape(4)

# %%
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, reg.predict(X), color='red', label='OLS')  # Original Least Squares line

plt.plot(X, y_pred, color='#1f77b4', label='b = {}'.format(b))        
plt.plot(X, y_pred1, color='#ff7f0e', label='b = {}'.format(b))      
plt.plot(X, y_pred2, color='#2ca02c', label='b = {}'.format(b))     
plt.plot(X, y_pred3, color='#d62728', label='b = {}'.format(b))       
   
plt.legend()
plt.title("Different Predictions for Changing b")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %%
# iteration 4
slope=-2* np.sum(y - (m * X.ravel()) - b)
slope
# Out:
# 51.90085325235884

# %%
step_size=lr*slope
step_size
# Out:
# 5.190085325235884

# %%
b = b - step_size
b
# Out:
# 27.45722559157049

# %%
y_pred4=((m * X) + b).reshape(4)

# %%
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, reg.predict(X), color='red', label='OLS')  # Original Least Squares line

plt.plot(X, y_pred, color='#1f77b4', label='b = {}'.format(b))        
plt.plot(X, y_pred1, color='#ff7f0e', label='b = {}'.format(b))      
plt.plot(X, y_pred2, color='#2ca02c', label='b = {}'.format(b))     
plt.plot(X, y_pred3, color='#d62728', label='b = {}'.format(b))       
plt.plot(X, y_pred4, color='black', label='b = {}'.format(b))   
plt.title("Different Predictions for Changing b")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %%
# iteration 5
slope=-2* np.sum(y - (m * X.ravel()) - b)
slope
# Out:
# 10.380170650471769

# %%
step_size=lr*slope
step_size
# Out:
# 1.038017065047177

# %%
b = b - step_size
b
# Out:
# 26.419208526523313

# %%
y_pred5=((m * X) + b).reshape(4)

# %%
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, reg.predict(X), color='red', label='OLS')  # Original Least Squares line

plt.plot(X, y_pred, color='#1f77b4', label='b = b0')        # blue
plt.plot(X, y_pred1, color='#ff7f0e', label='b = b1')       # orange
plt.plot(X, y_pred2, color='#2ca02c', label='b = b2')       # green
plt.plot(X, y_pred3, color='#d62728', label='b = b3')       # red
plt.plot(X, y_pred4, color='#9467bd', label='b = b4')       # purple
plt.plot(X, y_pred5, color='black', label='b = b5')       # brown  
plt.legend()
plt.title("Different Predictions for Changing b")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# %%
m = 78.35
b = -100
lr = 0.01
epochs=100

for i in range(epochs):

    slope = -2 * np.sum( y- (m * X.ravel()) - b)

    b = b - (lr * slope)

    y_pred=(m * X) + b
    
    plt.plot(X,y_pred)
plt.scatter(X,y);
plt.figure(figsize=(8,8));

# %% [markdown]
# ## **2. From Scratch**

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [28.12597332]
# -2.2710144261783816

# %%
y_pred = lr.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6345158782661013

# %%
class GDRegressor:
    
    def __init__(self,learning_rate,epochs):
        self.m = 100
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X,y):
        # calcualte the b using GD
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())
            
            self.b = self.b - (self.lr * loss_slope_b)
            self.m = self.m - (self.lr * loss_slope_m)
        print(self.m,self.b)
        
    def predict(self,X):
        return self.m * X + self.b

# %%
gd = GDRegressor(0.001,50)

# %%
gd.fit(X_train,y_train)
# Out:
# 28.159367347119066 -2.3004574196824854

# %%
y_pred = gd.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6343842836315579
