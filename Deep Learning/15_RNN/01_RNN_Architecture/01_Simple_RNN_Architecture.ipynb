# %%
import tensorflow
from tensorflow import keras
from keras import  Sequential
from keras.layers import Dense, SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(3,input_shape=(4,5)))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_3 (SimpleRNN)        │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Weights of First Input Layer
print(model.get_weights()[0].shape)
model.get_weights()[0]
# Out:
# (5, 3)
# array([[ 0.84985226, -0.65966594, -0.22582358],
#        [ 0.8498412 ,  0.7614258 ,  0.5429092 ],
#        [ 0.05572474, -0.8368602 , -0.86181474],
#        [ 0.54601604,  0.55820066, -0.82813114],
#        [ 0.43254048, -0.16572177, -0.5307504 ]], dtype=float32)

# %%
# Weights of Feedback
print(model.get_weights()[1].shape)
model.get_weights()[1]
# Out:
# (3, 3)
# array([[-0.24309957, -0.02982926,  0.9695426 ],
#        [ 0.5268652 ,  0.83517206,  0.15779933],
#        [-0.81444204,  0.54917914, -0.18731391]], dtype=float32)

# %%
# Biases of First Input Layer
print(model.get_weights()[2].shape)
model.get_weights()[2]
# Out:
# (3,)
# array([0., 0., 0.], dtype=float32)

# %%
# Weights of Second Input Layer
print(model.get_weights()[3].shape)
model.get_weights()[3]
# Out:
# (3, 1)
# array([[-0.79038095],
#        [ 0.8738109 ],
#        [-1.177645  ]], dtype=float32)

# %%
# Bias of Output Layer
print(model.get_weights()[4].shape)
model.get_weights()[4]
# Out:
# (1,)
# array([0.], dtype=float32)
